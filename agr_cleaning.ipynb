# %%
# transformations/clean_fakestore_products.py
import pandas as pd
from sqlalchemy import create_engine
import re

server = "localhost"
database = "agr_staging_db"

connection_string = (
    f"mssql+pyodbc://@{server}/{database}"
    "?driver=ODBC+Driver+18+for+SQL+Server"
    "&TrustServerCertificate=yes"
)
staging_engine = create_engine(connection_string)

server = "localhost"
database = "agr_cleaning_db"

connection_string = (
    f"mssql+pyodbc://@{server}/{database}"
    "?driver=ODBC+Driver+18+for+SQL+Server"
    "&TrustServerCertificate=yes"
)
cleaning_engine = create_engine(connection_string)

# Read from staging table
df = pd.read_sql("SELECT * FROM irrigated_land_data", staging_engine)
df=df.drop('Note',axis=1)
df.drop_duplicates()
df.info()
newest_years=df[df['Year']>=2000]
newest_years.sort_values(by='Year')
newest_years.info()
newest_years
newest_years.to_csv('F:\رواد مصر تراك تحليل البيانات\Tasks & Practices\Agriculture project\irrigated_land_edited.csv')
df.to_sql("clean_irrigated_land", cleaning_engine, if_exists="replace", index=False)
print("Data cleaned and loaded into cleaning_db successfully.")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9038 entries, 111 to 22614
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ï»¿Domain Code    9038 non-null   object
#  1   Domain            9038 non-null   object
#  2   Area Code (M49)   9038 non-null   int64
#  3   Area              9038 non-null   object
#  4   Element Code      9038 non-null   int64
#  5   Element           9038 non-null   object
#  6   Item Code         9038 non-null   object
#  7   Item              9038 non-null   object
#  8   Year Code         9038 non-null   int64
#  9   Year              9038 non-null   int64
#  10  Unit              9038 non-null   object
#  11  Value             9014 non-null   float64
#  12  Flag              9038 non-null   object
#  13  Flag Description  9038 non-null   object
#  14  Note              273 non-null    object
# dtypes: float64(1), int64(4), object(10)
# memory usage: 1.1+ MB
# ...

# %%
# transformations/clean_fakestore_products.py
import pandas as pd
from sqlalchemy import create_engine
import re

server = "localhost"
database = "agr_staging_db"

connection_string = (
    f"mssql+pyodbc://@{server}/{database}"
    "?driver=ODBC+Driver+18+for+SQL+Server"
    "&TrustServerCertificate=yes"
)
staging_engine = create_engine(connection_string)

server = "localhost"
database = "agr_cleaning_db"

connection_string = (
    f"mssql+pyodbc://@{server}/{database}"
    "?driver=ODBC+Driver+18+for+SQL+Server"
    "&TrustServerCertificate=yes"
)
cleaning_engine = create_engine(connection_string)

# Read from staging table
df = pd.read_sql("SELECT * FROM rainful_Temperature_data", staging_engine)
# df=df.isnull().sum()
# df.drop_duplicates()
# df.info()

unpivoted_df = pd.melt(df, id_vars=['PARAMETER', 'YEAR', 'LAT', 'LON'], var_name='MONTH', value_name='TEMPERATURE')
newest_years=unpivoted_df[unpivoted_df['YEAR']>=2000]
newest_years.sort_values(by='YEAR')
newest_years.info()
newest_years
# newest_years.to_csv(r'F:\رواد مصر تراك تحليل البيانات\Tasks & Practices\Agriculture project\rainfull_temperature_edited.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 172900 entries, 0 to 172899
# Data columns (total 6 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   PARAMETER    172900 non-null  object
#  1   YEAR         172900 non-null  int64
#  2   LAT          172900 non-null  float64
#  3   LON          172900 non-null  float64
#  4   MONTH        172900 non-null  object
#  5   TEMPERATURE  172900 non-null  float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 7.9+ MB
#        PARAMETER  YEAR   LAT     LON MONTH  TEMPERATURE
# 0            T2M  2019  25.5  29.375   JAN        10.48
# 1            T2M  2019  25.5  30.000   JAN        10.72
# 2            T2M  2019  25.5  30.625   JAN        11.71
# 3            T2M  2019  25.5  31.250   JAN        10.31
# 4            T2M  2019  25.5  31.875   JAN        10.90
# ...          ...   ...   ...     ...   ...          ...
# 172895       T2M  2019  25.5  26.250   ANN        21.28
# ...

# %%
# transformations/clean_fakestore_products.py
import pandas as pd
from sqlalchemy import create_engine
import re

server = "localhost"
database = "agr_staging_db"

connection_string = (
    f"mssql+pyodbc://@{server}/{database}"
    "?driver=ODBC+Driver+18+for+SQL+Server"
    "&TrustServerCertificate=yes"
)
staging_engine = create_engine(connection_string)

server = "localhost"
database = "agr_cleaning_db"

connection_string = (
    f"mssql+pyodbc://@{server}/{database}"
    "?driver=ODBC+Driver+18+for+SQL+Server"
    "&TrustServerCertificate=yes"
)
cleaning_engine = create_engine(connection_string)

# Read from staging table
df = pd.read_sql("SELECT * FROM arable_land_data", staging_engine)
df=df.isnull().sum()
df.drop_duplicates()
df.info()
df
unpivoted_df = pd.melt(df, id_vars=['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code'], var_name='YEAR', value_name='VALUE')
unpivoted_df
newest_years=unpivoted_df[unpivoted_df['YEAR']>='2000']
newest_years.sort_values(by='YEAR')
newest_years.info()
newest_years=newest_years.dropna(subset=['YEAR','VALUE'])
newest_years.info()
newest_years
# newest_years.to_csv(r'F:\رواد مصر تراك تحليل البيانات\Tasks & Practices\Agriculture project\arable_land_data_edited.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6012 entries, 10640 to 17023
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    6012 non-null   object
#  1   Country Code    6012 non-null   object
#  2   Indicator Name  6012 non-null   object
#  3   Indicator Code  6012 non-null   object
#  4   YEAR            6012 non-null   object
#  5   VALUE           6012 non-null   object
# dtypes: object(6)
# memory usage: 328.8+ KB
#                       Country Name Country Code                Indicator Name  \
# 10640                        Aruba          ABW  Arable land (% of land area)
# 10641  Africa Eastern and Southern          AFE  Arable land (% of land area)
# 10642                  Afghanistan          AFG  Arable land (% of land area)
# 10643   Africa Western and Central          AFW  Arable land (% of land area)
# ...

# %%
# transformations/clean_fakestore_products.py
import pandas as pd
from sqlalchemy import create_engine
import re

server = "localhost"
database = "agr_staging_db"

connection_string = (
    f"mssql+pyodbc://@{server}/{database}"
    "?driver=ODBC+Driver+18+for+SQL+Server"
    "&TrustServerCertificate=yes"
)
staging_engine = create_engine(connection_string)

server = "localhost"
database = "agr_cleaning_db"

connection_string = (
    f"mssql+pyodbc://@{server}/{database}"
    "?driver=ODBC+Driver+18+for+SQL+Server"
    "&TrustServerCertificate=yes"
)
cleaning_engine = create_engine(connection_string)

# Read from staging table
df = pd.read_sql("SELECT * FROM co2_emmisions_data", staging_engine)
df
# df=df.isnull().sum()
df.drop_duplicates()
# df.info()
# df

unpivoted_df = pd.melt(df, id_vars=['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code'], var_name='YEAR', value_name='VALUE')
unpivoted_df
newest_years=unpivoted_df[unpivoted_df['YEAR']>='2000']
newest_years.sort_values(by='YEAR')

newest_years=newest_years.dropna(subset=['YEAR','VALUE'])
newest_years.info()
newest_years
# newest_years.to_csv(r'F:\رواد مصر تراك تحليل البيانات\Tasks & Practices\Agriculture project\co2_emmisions_data_edited.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3900 entries, 10641 to 17289
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    3900 non-null   object
#  1   Country Code    3900 non-null   object
#  2   Indicator Name  3900 non-null   object
#  3   Indicator Code  3900 non-null   object
#  4   YEAR            3900 non-null   object
#  5   VALUE           3900 non-null   object
# dtypes: object(6)
# memory usage: 213.3+ KB
#                       Country Name Country Code  \
# 10641  Africa Eastern and Southern          AFE
# 10642                  Afghanistan          AFG
# 10643   Africa Western and Central          AFW
# 10645                      Albania          ALB
# 10647                   Arab World          ARB
# ...                            ...          ...
# 17281                     Viet Nam          VNM
# 17283                        World          WLD
# ...

# %%
# transformations/clean_fakestore_products.py
import pandas as pd
from sqlalchemy import create_engine
import re

server = "localhost"
database = "agr_staging_db"

connection_string = (
    f"mssql+pyodbc://@{server}/{database}"
    "?driver=ODBC+Driver+18+for+SQL+Server"
    "&TrustServerCertificate=yes"
)
staging_engine = create_engine(connection_string)

server = "localhost"
database = "agr_cleaning_db"

connection_string = (
    f"mssql+pyodbc://@{server}/{database}"
    "?driver=ODBC+Driver+18+for+SQL+Server"
    "&TrustServerCertificate=yes"
)
cleaning_engine = create_engine(connection_string)

# Read from staging table
df = pd.read_sql("SELECT * FROM fertilizer_use_data", staging_engine)
# df=df.isnull().sum()
# df.drop_duplicates()
# df.info()
# df

unpivoted_df = pd.melt(df, id_vars=['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code'], var_name='YEAR', value_name='VALUE')
# unpivoted_df
newest_years=unpivoted_df[unpivoted_df['YEAR']>='2000']
newest_years.sort_values(by='YEAR')

newest_years=newest_years[~(newest_years['YEAR'].astype(str).str.contains("Unnamed")) & ~(newest_years['YEAR'].astype(str).str.contains("2024"))]
newest_years['VALUE']=newest_years['VALUE'].fillna(method="ffill").fillna(method="bfill")
# newest_years=newest_years.dropna(subset=['YEAR'])
newest_years.info()
newest_years
# newest_years.to_csv(r'F:\رواد مصر تراك تحليل البيانات\Tasks & Practices\Agriculture project\fertilizer_use_data_edited.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6384 entries, 10640 to 17023
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    6384 non-null   object
#  1   Country Code    6384 non-null   object
#  2   Indicator Name  6384 non-null   object
#  3   Indicator Code  6384 non-null   object
#  4   YEAR            6384 non-null   object
#  5   VALUE           6384 non-null   float64
# dtypes: float64(1), object(5)
# memory usage: 349.1+ KB
# C:\Users\DELL\AppData\Local\Temp\ipykernel_2908\3775975392.py:39: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   newest_years['VALUE']=newest_years['VALUE'].fillna(method="ffill").fillna(method="bfill")
# ...

# %%
# transformations/clean_fakestore_products.py
import pandas as pd
from sqlalchemy import create_engine
import re

server = "localhost"
database = "agr_staging_db"

connection_string = (
    f"mssql+pyodbc://@{server}/{database}"
    "?driver=ODBC+Driver+18+for+SQL+Server"
    "&TrustServerCertificate=yes"
)
staging_engine = create_engine(connection_string)

server = "localhost"
database = "agr_cleaning_db"

connection_string = (
    f"mssql+pyodbc://@{server}/{database}"
    "?driver=ODBC+Driver+18+for+SQL+Server"
    "&TrustServerCertificate=yes"
)
cleaning_engine = create_engine(connection_string)

# Read from staging table
df = pd.read_sql("SELECT * FROM population_data", staging_engine)

# df=df.isnull().sum()
df.drop_duplicates()
# df.info()
# df

unpivoted_df = pd.melt(df, id_vars=['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code'], var_name='YEAR', value_name='VALUE')
unpivoted_df
newest_years=unpivoted_df[unpivoted_df['YEAR']>='2000']
newest_years.sort_values(by='YEAR')

newest_years=newest_years.dropna(subset=['YEAR','VALUE'])
newest_years.info()
newest_years
newest_years.to_csv(r'F:\رواد مصر تراك تحليل البيانات\Tasks & Practices\Agriculture project\population_data_edited.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6625 entries, 10640 to 17289
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    6625 non-null   object
#  1   Country Code    6625 non-null   object
#  2   Indicator Name  6625 non-null   object
#  3   Indicator Code  6625 non-null   object
#  4   YEAR            6625 non-null   object
#  5   VALUE           6625 non-null   object
# dtypes: object(6)
# memory usage: 362.3+ KB
